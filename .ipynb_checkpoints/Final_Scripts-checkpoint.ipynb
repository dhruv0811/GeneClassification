# %%
from URSGeneClassifier import *
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn import metrics, model_selection, svm, linear_model
from sklearn.utils import shuffle
from random import randrange
import numpy as np
import pickle
import os
import pandas
import matplotlib.pyplot as plt
import scipy.sparse as sps

# %%
dict = re_id_genes_to_dict("MIT.txt", "MIT_restruc.txt")

# %%
sp_matrix, dim = create_sparse_matrix(dict, "MIT_restruc.txt")
# Out:
# No. of distinct genes in network: 1530
# Creating sparse matrix...
# Created sparse matrix.

# %%
print(sp_matrix[:,1])
print(dict['2989'])
# Out:
#   (0, 0)	0.0003982945804063
#   (2, 0)	0.0009619630666234
#   (8, 0)	0.0004887925803754
#   (22, 0)	0.0019113925708528
#   (27, 0)	0.0001139350087265
#   (40, 0)	0.0016217968551106
#   (43, 0)	0.000338647344142
#   (49, 0)	0.003481481494843
#   (60, 0)	0.0058220697876055
#   (63, 0)	0.0019445773666414
#   (64, 0)	0.0009774230905018
#   (70, 0)	0.002155354811768
#   (72, 0)	0.0011046943201252
#   (83, 0)	0.000525034371616
#   (85, 0)	0.0018542155624062
#   (89, 0)	0.0001256728246701
#   (97, 0)	0.0007196501592445
#   (101, 0)	0.0005809590746371
#   (107, 0)	0.0017761225179137
#   (113, 0)	0.0017341100725534
#   (120, 0)	6.5324448613531e-05
#   (125, 0)	0.0012626461594589
#   (134, 0)	0.0057636031417937
#   (143, 0)	0.0005117636851159
#   (145, 0)	0.0001676563908358
#   (148, 0)	0.0002487885120579
#   (150, 0)	0.000688536015499
#   (157, 0)	0.0025868777301554
#   (160, 0)	0.000804083373466
#   (161, 0)	0.0026764756885938
#   (164, 0)	0.0033567599104923
#   (165, 0)	0.0003254677395917
# ...

# %%
positiveClass, set_pos = create_positive_class('data/alz/alz.dis.txt', sp_matrix, dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-444263df2872> in <module>
# ----> 1 positiveClass, set_pos = create_positive_class('data/alz/alz.dis.txt', sp_matrix)
#
# ~/GeneClassification/URSGeneClassifier.py in create_positive_class(posclass, matrix)
#      84                 for line in alz:
#      85                         gene_id = str(line.strip().split("\t")[0])
# ---> 86                         if gene_id in dict.keys():
#      87                                 positiveClass[count] = matrix[dict[gene_id]]
#      88                                 count += 1
#
# TypeError: descriptor 'keys' of 'dict' object needs an argument

# %%
sp_matrix.shape
# Out:
# (1530, 1530)

# %%
print(positiveClass.shape)
# Out:
# (631, 25690)

# %%
negativeClass, set_neg = create_negative_class(set_pos, sp_matrix)

# %%
print(len(set_neg))
print(len(set_pos))
print(negativeClass.shape)
print(positiveClass.shape)
# Out:
# 631
# 631
# (631, 25690)
# (631, 25690)

# %%
fullTrain = create_full_training_class(positiveClass, negativeClass)

# %%
print(fullTrain.shape)
# Out:
# (1262, 25691)

# %%
X_train, X_test, y_train, y_test, X_full, y_full = load_and_format_training_data('saved_full_train.pkl')

# %%
svm_linear = svm.SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
evaluate_model(svm_linear, X_full, y_full, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-0d0d7b507a3e> in <module>
#       1 svm_linear = svm.SVC(kernel='linear')
#       2 svm_linear.fit(X_train, y_train)
# ----> 3 evaluate_model(svm_linear, X_full, y_full, X_test, y_test)
#
# <ipython-input-119-a2b2f43adbe6> in evaluate_model(model, X_full, y_full, X_test, y_test)
#       1 def evaluate_model(model, X_full, y_full, X_test, y_test):
# ----> 2     cv_scores = cross_val_score(model, X_full, y_full, cv=5)
#       3     print("\n5 fold cross validation scores:")
#       4     print(cv_scores)
#       5     print("\n5 fold cross validation score average:")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ...

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
evaluate_model(rfc, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [0.65612648 0.6798419  0.67063492 0.65079365 0.67063492]
#
# 5 fold cross validation score average:
# 0.6656063743020264
#
# AUROC score for linear kernel:
# 0.6500362137166416
# 132 wrong out of 379
# Accuracy: 0.6517150395778364
