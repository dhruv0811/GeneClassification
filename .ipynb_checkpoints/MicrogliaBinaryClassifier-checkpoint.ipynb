# %%
from URSGeneClassifier import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm, linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.naive_bayes import GaussianNB

# %%
X_train, X_test, y_train, y_test, X_full, y_full = load_and_format_training_data('saved_full_train.pkl')

# %%
svm_linear = svm.SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
evaluate_model(svm_linear, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [0.48484848 0.48484848 0.53125    0.5        0.46875   ]
#
# 5 fold cross validation score average:
# 0.49393939393939396
#
# AUROC score:
# 0.5
# 26 wrong out of 49
# Accuracy: 0.4693877551020408

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
evaluate_model(rfc, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [0.57575758 0.63636364 0.625      0.6875     0.53125   ]
#
# 5 fold cross validation score average:
# 0.6111742424242423
#
# AUROC score:
# 0.6839464882943144
# 15 wrong out of 49
# Accuracy: 0.6938775510204082

# %%
knn = KNeighborsClassifier(n_neighbors=100)
knn.fit(X_train, y_train)
evaluate_model(knn, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [0.48484848 0.51515152 0.5        0.5        0.5       ]
#
# 5 fold cross validation score average:
# 0.5
#
# AUROC score:
# 0.5
# 26 wrong out of 49
# Accuracy: 0.4693877551020408

# %%
dtc = DecisionTreeClassifier(max_depth=100)
dtc.fit(X_train, y_train)
evaluate_model(dtc, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [0.63636364 0.54545455 0.625      0.53125    0.40625   ]
#
# 5 fold cross validation score average:
# 0.5488636363636363
#
# AUROC score:
# 0.4958193979933111
# 24 wrong out of 49
# Accuracy: 0.5102040816326531

# %%
mlp = MLPClassifier(max_iter=1000)
mlp.fit(X_train, y_train)
evaluate_model(mlp, X_full, y_full, X_test, y_test)
# Out:
# /Users/dhruv/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/dhruv/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 5 fold cross validation scores:
# [0.45454545 0.63636364 0.6875     0.53125    0.5       ]
#
# 5 fold cross validation score average:
# 0.5619318181818181
#
# AUROC score:
# 0.5384615384615384
# /Users/dhruv/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 24 wrong out of 49
# Accuracy: 0.5102040816326531

# %%
mlp = MLPRegressor(max_iter=1000)
mlp.fit(X_train, y_train)
evaluate_model(mlp, X_full, y_full, X_test, y_test)
# Out:
# 5 fold cross validation scores:
# [-0.04090688 -0.2060909  -0.04650558 -0.00796287 -0.01498048]
#
# 5 fold cross validation score average:
# -0.06328934209085549
#
# AUROC score:
# 0.5560200668896321
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b81731690a3f> in <module>
#       1 mlp = MLPRegressor(max_iter=1000)
#       2 mlp.fit(X_train, y_train)
# ----> 3 evaluate_model(mlp, X_full, y_full, X_test, y_test)
#
# ~/GeneClassification/URSGeneClassifier.py in evaluate_model(model, X_full, y_full, X_test, y_test)
#     156         print("\nAUROC score:")
#     157         print(roc_auc_score(y_test, model.predict(X_test)))
# --> 158         metrics.plot_roc_curve(model, X_test, y_test)
#     159         plt.show()
#     160
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/roc_curve.py in plot_roc_curve(estimator, X, y, sample_weight, drop_intermediate, response_method, name, ax, pos_label, **kwargs)
#     210     check_matplotlib_support('plot_roc_curve')
#     211
# --> 212     y_pred, pos_label = _get_response(
#     213         X, estimator, response_method, pos_label=pos_label)
#     214
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/base.py in _get_response(X, estimator, response_method, pos_label)
#      84
#      85     if not is_classifier(estimator):
# ---> 86         raise ValueError(classification_error)
#      87
#      88     prediction_method = _check_classifier_response_method(
#
# ValueError: MLPRegressor should be a binary classifier
