# %%
from URSGeneClassifier import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm, linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt

# %%
X_train, X_test, y_train, y_test, X_full, y_full = load_and_format_training_data('alz/microglia/saved_full_train.pkl')
scores = {}

# %%
svm_linear = svm.SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
evaluate_model(svm_linear, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [0.48484848 0.48484848 0.53125    0.5        0.5       ]
#
# 5 fold cross validation score average:
# 0.500189393939394
#
# AUROC score:
# 0.5
# 29 wrong out of 49
# Accuracy: 0.40816326530612246

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
evaluate_model(rfc, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [0.54545455 0.60606061 0.625      0.59375    0.5625    ]
#
# 5 fold cross validation score average:
# 0.5865530303030303
#
# AUROC score:
# 0.5663793103448276
# 22 wrong out of 49
# Accuracy: 0.5510204081632653

# %%
knn = KNeighborsClassifier(n_neighbors=100)
knn.fit(X_train, y_train)
evaluate_model(knn, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [0.51515152 0.48484848 0.5        0.5        0.5       ]
#
# 5 fold cross validation score average:
# 0.5
#
# AUROC score:
# 0.5
# 29 wrong out of 49
# Accuracy: 0.40816326530612246

# %%
dtc = DecisionTreeClassifier(max_depth=100)
dtc.fit(X_train, y_train)
evaluate_model(dtc, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [0.48484848 0.60606061 0.625      0.5625     0.5       ]
#
# 5 fold cross validation score average:
# 0.5556818181818182
#
# AUROC score:
# 0.4724137931034483
# 27 wrong out of 49
# Accuracy: 0.44897959183673475

# %%
mlp = MLPClassifier(max_iter=1000)
mlp.fit(X_train, y_train)
evaluate_model(mlp, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [0.48484848 0.51515152 0.59375    0.78125    0.40625   ]
#
# 5 fold cross validation score average:
# 0.55625
#
# AUROC score:
# 0.5198275862068966
# /Users/dhruv/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 22 wrong out of 49
# Accuracy: 0.5510204081632653

# %%
mlp = MLPRegressor(max_iter=1000)
mlp.fit(X_train, y_train)
evaluate_model(mlp, X_full, y_full, X_test, y_test, scores)
# Out:
# 5 fold cross validation scores:
# [ 0.00172284 -0.00921684 -0.00817793 -0.00897156 -0.01107575]
#
# 5 fold cross validation score average:
# -0.007143849788160827
#
# AUROC score:
# 0.4913793103448276
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b45463883816> in <module>
#       1 mlp = MLPRegressor(max_iter=1000)
#       2 mlp.fit(X_train, y_train)
# ----> 3 evaluate_model(mlp, X_full, y_full, X_test, y_test, scores)
#
# ~/GeneClassification/URSGeneClassifier.py in evaluate_model(model, X_full, y_full, X_test, y_test, scores)
#     136         print("\nAUROC score:")
#     137         print(roc_auc_score(y_test, model.predict(X_test)))
# --> 138         metrics.plot_roc_curve(model, X_test, y_test)
#     139         plt.show()
#     140
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/roc_curve.py in plot_roc_curve(estimator, X, y, sample_weight, drop_intermediate, response_method, name, ax, pos_label, **kwargs)
#     210     check_matplotlib_support('plot_roc_curve')
#     211
# --> 212     y_pred, pos_label = _get_response(
#     213         X, estimator, response_method, pos_label=pos_label)
#     214
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/base.py in _get_response(X, estimator, response_method, pos_label)
#      84
#      85     if not is_classifier(estimator):
# ---> 86         raise ValueError(classification_error)
#      87
#      88     prediction_method = _check_classifier_response_method(
#
# ValueError: MLPRegressor should be a binary classifier

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(scores.keys(), scores.values(), color ='blue',
        width = 0.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a81eeeb4ac0b> in <module>
# ----> 1 fig = plt.figure(figsize = (10, 5))
#       2
#       3 # creating the bar plot
#       4 plt.bar(courses, values, color ='maroon',
#       5         width = 0.4)
#
# TypeError: 'module' object is not callable
